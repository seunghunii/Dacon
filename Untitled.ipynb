# %% [markdown]
# ## prepare

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
dirr = 'C:/Users/rsh15/Desktop/seunghuni/dataset/dacon/cardfraud/'
train = pd.read_csv(dirr+'train.csv').iloc[:,1:]
test  = pd.read_csv(dirr+'test.csv').iloc[:,1:]

# %%
train_y = train['credit'].astype(int)

# %%
train
# Out:
#       gender car reality  child_num  income_total           income_type  \
# 0          F   N       N          0      202500.0  Commercial associate
# 1          F   N       Y          1      247500.0  Commercial associate
# 2          M   Y       Y          0      450000.0               Working
# 3          F   N       Y          0      202500.0  Commercial associate
# 4          F   Y       Y          0      157500.0         State servant
# ...      ...  ..     ...        ...           ...                   ...
# 26452      F   N       N          2      225000.0         State servant
# 26453      F   N       Y          1      180000.0               Working
# 26454      F   Y       N          0      292500.0               Working
# 26455      M   N       Y          0      171000.0               Working
# 26456      F   N       N          0       81000.0               Working
#
#                             edu_type           family_type  \
# 0                   Higher education               Married
# 1      Secondary / secondary special        Civil marriage
# 2                   Higher education               Married
# 3      Secondary / secondary special               Married
# 4                   Higher education               Married
# ...                              ...                   ...
# 26452  Secondary / secondary special               Married
# 26453               Higher education             Separated
# 26454  Secondary / secondary special        Civil marriage
# 26455              Incomplete higher  Single / not married
# 26456  Secondary / secondary special        Civil marriage
#
#                 house_type  DAYS_BIRTH  DAYS_EMPLOYED  FLAG_MOBIL  work_phone  \
# 0      Municipal apartment      -13899          -4709           1           0
# 1        House / apartment      -11380          -1540           1           0
# 2        House / apartment      -19087          -4434           1           0
# 3        House / apartment      -15088          -2092           1           0
# 4        House / apartment      -15037          -2105           1           0
# ...                    ...         ...            ...         ...         ...
# 26452    House / apartment      -12079          -1984           1           0
# 26453    House / apartment      -15291          -2475           1           0
# 26454         With parents      -10082          -2015           1           0
# 26455    House / apartment      -10145           -107           1           0
# 26456    House / apartment      -19569          -1013           1           0
#
#        phone  email      occyp_type  family_size  begin_month  credit
# 0          0      0             NaN          2.0         -6.0     1.0
# 1          0      1        Laborers          3.0         -5.0     1.0
# 2          1      0        Managers          2.0        -22.0     2.0
# 3          1      0     Sales staff          2.0        -37.0     0.0
# 4          0      0        Managers          2.0        -26.0     2.0
# ...      ...    ...             ...          ...          ...     ...
# 26452      0      0      Core staff          4.0         -2.0     1.0
# 26453      0      0             NaN          2.0        -47.0     2.0
# 26454      0      0      Core staff          2.0        -25.0     2.0
# 26455      0      0        Laborers          1.0        -59.0     2.0
# 26456      0      0  Security staff          2.0         -9.0     2.0
#
# [26457 rows x 19 columns]

# %% [markdown]
# ## vis

# %% [markdown]
# ### binary(gender, car, reality)

# %%
sns.displot(data=train,x='credit',hue='gender',kind='kde')
sns.displot(data=train,x='credit',hue='car',kind='kde')
sns.displot(data=train,x='credit',hue='reality',kind='kde')

# %% [markdown]
# #### with car & reality both?

# %%
car_reality = np.where((train['car']=='Y') & (train['reality']=='Y'),1,0)
car_reality
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
fig,ax = plt.subplots(1,2,figsize=(15,5))

df_vis = train.groupby([car_reality,'credit']).size().reset_index(name='countt')

ax[0].pie(df_vis[df_vis['level_0']==0]['countt'],autopct='%.1f%%',
          labels=['credit'+str(a) for a in range(0,3)])
ax[0].set_title('Having Car & Reality')

ax[1].pie(df_vis[df_vis['level_0']==1]['countt'],autopct='%.1f%%',
          labels=['credit'+str(a) for a in range(0,3)])
ax[1].set_title('No Car & Reality')
# Out:
# ([<matplotlib.patches.Wedge at 0x2934b0b75e0>,
#   <matplotlib.patches.Wedge at 0x2934b197970>,
#   <matplotlib.patches.Wedge at 0x2934b197f70>],
#  [Text(1.0189369515826188, 0.41444841500423224, 'credit0'),
#   Text(0.0560404476436976, 1.0985715580825375, 'credit1'),
#   Text(-0.4658209098864616, -0.9964993125499632, 'credit2')],
#  [Text(0.5557837917723374, 0.22606277182049028, '12.3%'),
#   Text(0.030567516896562324, 0.5992208498632022, '23.8%'),
#   Text(-0.25408413266534263, -0.5435450795727071, '63.9%')])
# Text(0.5, 1.0, 'Having Car & Reality')
# ([<matplotlib.patches.Wedge at 0x2934b1a7610>,
#   <matplotlib.patches.Wedge at 0x2934b1a7c70>,
#   <matplotlib.patches.Wedge at 0x2934b1b92b0>],
#  [Text(1.0249359130311364, 0.3993824910772018, 'credit0'),
#   Text(0.10164691127313619, 1.0952935247816593, 'credit1'),
#   Text(-0.492384205636868, -0.9836451565678299, 'credit2')],
#  [Text(0.5590559525624379, 0.21784499513301914, '11.8%'),
#   Text(0.05544376978534701, 0.5974328316990868, '23.4%'),
#   Text(-0.26857320307465526, -0.5365337217642708, '64.8%')])
# Text(0.5, 1.0, 'No Car & Reality')

# %% [markdown]
# ### child num

# %%
sns.countplot(train['child_num'])
# Out:
# C:\Users\rsh15\anaconda3\envs\simon_env\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='child_num', ylabel='count'>

# %%
fig,ax = plt.subplots(1,3,figsize=(18,8))

df_vis = train.groupby(['credit','child_num']).size().reset_index(name='countt')

ax[0].pie(df_vis[df_vis['credit']==0]['countt'],autopct='%.1f%%');
ax[1].pie(df_vis[df_vis['credit']==1]['countt'],autopct='%.1f%%');
ax[2].pie(df_vis[df_vis['credit']==2]['countt'],autopct='%.1f%%');

# %% [markdown]
# ### income_total

# %%
fig,ax = plt.subplots(2,1,figsize=(20,11))

sns.kdeplot(train['income_total'],ax=ax[0])
sns.kdeplot(data=train,x='income_total',hue='credit',ax=ax[1])
# Out:
# <AxesSubplot:xlabel='income_total', ylabel='Density'>
# <AxesSubplot:xlabel='income_total', ylabel='Density'>

# %% [markdown]
# ### income_type

# %% [markdown]
# 직업별 credit에 큰 차이가 없음

# %%
fig,ax = plt.subplots(2,3,figsize=(18,10))
idxx = [(0,0),(0,1),(0,2),(1,0),(1,1),(1,2)]
income_idx = train['income_type'].unique()

for k in range(0,5):
    ax[idxx[k]].pie(df_vis[df_vis['income_type']==income_idx[k]]['countt'],autopct='%.1f%%');
ax[1,2].remove()
# Out:
# ([<matplotlib.patches.Wedge at 0x29357abbd00>,
#   <matplotlib.patches.Wedge at 0x29357afb7c0>,
#   <matplotlib.patches.Wedge at 0x29357afbdc0>],
#  [Text(1.0148222287067419, 0.42442413235192156, ''),
#   Text(0.10736823252190258, 1.0947474880743608, ''),
#   Text(-0.5214516564002041, -0.9685495186295245, '')],
#  [Text(0.5535393974764046, 0.23150407219195718, '12.6%'),
#   Text(0.058564490466492314, 0.5971349934951058, '21.7%'),
#   Text(-0.28442817621829314, -0.528299737434286, '65.7%')])
# ([<matplotlib.patches.Wedge at 0x29357b0a3d0>,
#   <matplotlib.patches.Wedge at 0x29357b0abe0>,
#   <matplotlib.patches.Wedge at 0x29357b1b2b0>],
#  [Text(1.0226048905569969, 0.4053137523066699, ''),
#   Text(0.05000184822627036, 1.0988629646930308, ''),
#   Text(-0.45137859789019397, -1.0031238016150763, '')],
#  [Text(0.5577844857583619, 0.22108022853091083, '12.0%'),
#   Text(0.027273735396147466, 0.5993797989234713, '24.5%'),
#   Text(-0.24620650794010576, -0.547158437244587, '63.5%')])
# ([<matplotlib.patches.Wedge at 0x293579d75b0>,
#   <matplotlib.patches.Wedge at 0x29357b1be20>,
#   <matplotlib.patches.Wedge at 0x29357b2a340>],
#  [Text(1.0188572498433561, 0.4146443107551738, ''),
#   Text(0.09294083800768119, 1.0960666041032499, ''),
#   Text(-0.4992464563868777, -0.9801800731422495, '')],
#  [Text(0.555740318096376, 0.22616962404827656, '12.3%'),
#   Text(0.050695002549644284, 0.5978545113290453, '22.7%'),
#   Text(-0.27231624893829687, -0.5346436762594088, '65.0%')])
# ([<matplotlib.patches.Wedge at 0x29357b2aa30>,
#   <matplotlib.patches.Wedge at 0x29357b37130>,
#   <matplotlib.patches.Wedge at 0x293579ed970>],
#  [Text(1.0221467926371717, 0.40646763007839, ''),
#   Text(0.05318647915523354, 1.098713428713361, ''),
#   Text(-0.4554142995104455, -1.001298065413796, '')],
#  [Text(0.5575346141657299, 0.2217096164063945, '12.0%'),
#   Text(0.029010806811945566, 0.5992982338436514, '24.4%'),
#   Text(-0.24840779973297022, -0.5461625811347978, '63.6%')])
# ([<matplotlib.patches.Wedge at 0x29357b37c70>,
#   <matplotlib.patches.Wedge at 0x29357b462b0>],
#  [Text(0.2447730130080499, 1.0724207066739067, ''),
#   Text(-0.2447729126007758, -1.0724207295912054, '')],
#  [Text(0.1335125525498454, 0.5849567490948581, '42.9%'),
#   Text(-0.13351249778224134, -0.5849567615952028, '57.1%')])
